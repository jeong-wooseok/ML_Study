# %% [markdown]
# # Surprise 패키지 활용한 추천
# 빠르고 최적화된 추천 시스텐 활용을 위해 surprise 활용해보자 <br>
# 설치 !conda install -c conda-forge scikit- <br>
# !pip install scikit-surprise

# %%
from surprise import SVD
from surprise import Dataset
from surprise import accuracy
from surprise.model_selection import train_test_split

# %% [markdown]
# ## 기본 실행
# <br> 데이터 불러와서 일반적으로 실행

# %%
import pandas as pd
from surprise import Reader

ratings = pd.read_csv('./ml-latest-small/ratings.csv')
ratings.to_csv('./ml-latest-small/ratings_noh.csv', index= False, header=False)

# %% [markdown]
# 서프라이즈로 데이터셋을 불러올때는 인덱스, 헤더를 지운 파일로 저장하고, 리더포멧을 지정하여 읽어온다

# %%
reader = Reader(line_format = 'user item rating timestamp', sep= ',', rating_scale = (0.5, 5))
data = Dataset.load_from_file('./ml-latest-small/ratings_noh.csv', reader = reader)

# %%
train_set, test_set = train_test_split(data, test_size= 0.25, random_state=0)

algo = SVD(n_factors=50, random_state=0)
algo.fit(train_set)
pred = algo.test(test_set)
accuracy.rmse(pred)
# Out:
# RMSE: 0.8682
# 0.8681952927143516

# %%
pred[:5] # 예측결과 확ㅣ
# Out:
# [Prediction(uid='63', iid='2000', r_ui=3.0, est=3.5016267817280697, details={'was_impossible': False}),
#  Prediction(uid='31', iid='788', r_ui=2.0, est=3.2840758900255937, details={'was_impossible': False}),
#  Prediction(uid='159', iid='6373', r_ui=4.0, est=2.804939396068158, details={'was_impossible': False}),
#  Prediction(uid='105', iid='81564', r_ui=3.0, est=3.9326180027723914, details={'was_impossible': False}),
#  Prediction(uid='394', iid='480', r_ui=3.0, est=3.3135580105479114, details={'was_impossible': False})]

# %% [markdown]
# ## 추천 알고리즘 클래스
# - SVD : 행렬 분해를 통한 잠재요인 협업 필터링
# - KNNBasic : 최근접 이웃 협업필터링
# - BaselineOnly : 사용자Bias와 아이템Bias를 감안한 SGD베이스라인 알고리즘 <br>
# [Surprise_알고리즘 관련 공식문서](http://surprise.readthedocs.io/en/stable/prediction_algorithms_package.html)

# %% [markdown]
# > svd 입력 파라미터
# - n_factors : 잠재요인 K의 개수, default는 100, 커질수록 정확도는 높아질 수 있으나 과적합 이슈 가능
# - n_epochs : SGD(Stochatic Gradient Descent) 수행 시 반복횟수, 디폴트는 20
# - biased(bool) : 베이스라인 사용자 편향 적용여부이며, 디폴트는 True <br>
#   : 아이템 평가 상 개인의 성향, 즉 편향적 요소를 반영하는 것으로, 베이스라인평점 = 전체평균평점 + 사용자편향점수 + 아이템편향점수

# %% [markdown]
# > 베이스라인 평점
# - 전체평균평점 = 모든 사용자의 아이템에 대한 평점을 평균한 값
# - 사용자편향점수 = 사용자별아이템 평점 평균 값 - 전체평균평점
# - 아이템편향점수 = 아이템별 평점 평균 값 - 전체평균평점
#
# 예시 : 사용자 A의 어벤저스 베이스라인 평점
# - 모든사용자 전체 평균평점 : 3.5
# - A사용자 전체영화 평균평점 : 3.0
# - 어벤저스 평균평점 : 4.2 <br>
# 늘 영화에 대한 판단을 깐깐하게 하는 A사용자의 어벤저스에 대한 베이스라인 평점은<br>
# 3.5 + (3.0-3.5) + (4.2-3.5) = 3.7

# %% [markdown]
# ## 교차검증과 하이퍼파라미터 튜닝
# - cross_validate()
# - GridSearchCV()

# %%
from surprise.model_selection import cross_validate

ratings = pd.read_csv('./ml-latest-small/ratings.csv')
reader = Reader(rating_scale=(0.5,5))
data = Dataset.load_from_df(ratings[['userId','movieId','rating']], reader)

algo = SVD(random_state=0)
cross_validate(algo, data, measures = ['MAE','RMSE'], cv=5, verbose = True)
# Out:
# Evaluating MAE, RMSE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# MAE (testset)     0.6659  0.6711  0.6706  0.6774  0.6712  0.6713  0.0037
# RMSE (testset)    0.8702  0.8739  0.8733  0.8775  0.8726  0.8735  0.0023
# Fit time          2.52    2.55    2.56    2.53    2.48    2.53    0.03
# Test time         0.05    0.13    0.05    0.05    0.05    0.07    0.03
# {'test_mae': array([0.66591716, 0.67113517, 0.67062096, 0.67742082, 0.67118181]),
#  'test_rmse': array([0.87023291, 0.8738905 , 0.87334349, 0.87746443, 0.87257607]),
#  'fit_time': (2.517595052719116,
#   2.547327995300293,
#   2.560128927230835,
#   2.534716844558716,
#   2.4824540615081787),
#  'test_time': (0.04940295219421387,
#   0.1275649070739746,
#   0.04861307144165039,
#   0.048146963119506836,
#   0.05282402038574219)}

# %%
from surprise.model_selection import GridSearchCV
from surprise import SVD

# 최적화할 파라미터를 딕셔너리 저장
param_grid = {'n_epochs': [20,40,60], 'n_factors':[50,100,200]}

# cv를 3개 폴드세트로 지정, 성능평가는 MAE, RMSE
gs = GridSearchCV(SVD, param_grid, measures = ['rmse','mae'], cv=3)
gs.fit(data)

# 최고 RMSE evaluation 점수와 그때의 하이퍼파라미터
print(gs.best_score['rmse'])
print(gs.best_params['rmse'])
# Out:
# 0.876711640622501
# {'n_epochs': 20, 'n_factors': 50}

# %% [markdown]
# ## Surprise를 이용한 개인화 영화 추천시스템 구축

# %%
# ## 다음 코드는 데이터세트를 분리하지 않고 통채로 넣어서 에러 발생
# data = Dataset.load_from_df(ratings[['userId','movieId','rating']],reader)
# algo = SVD(n_factors=50,random_state=0)
# algo.fit(data)

from surprise.dataset import DatasetAutoFolds

reader = Reader(line_format='user item rating timestamp', sep=',', rating_scale=(0.5,5))
data_folds = DatasetAutoFolds(ratings_file = './ml-latest-small/ratings_noh.csv', reader=reader) # datasetautofolds 클래스를 ratings_noh.csv파일 기반으로 생성
train_set = data_folds.build_full_trainset()
algo = SVD(n_factors=50,random_state=0)
algo.fit(train_set)

# %% [markdown]
# 영화속성정보 생성

# %%
movies = pd.read_csv('./ml-latest-small/movies.csv')

# userId = 9의 영화데이터 추출
usr_id = 9
mv_id = 42
movieIds = ratings[ratings['userId']==usr_id]['movieId']

if movieIds[movieIds == mv_id].count() == 0:
    print(f'사용자 아이디 {usr_id}는 영화 아이디 {mv_id}의 평점 없음')
print(movies[movies['movieId']==mv_id])
# Out:
# 사용자 아이디 9는 영화 아이디 42의 평점 없음
#     movieId                   title              genres
# 38       42  Dead Presidents (1995)  Action|Crime|Drama

# %%
uid = str(usr_id)
iid = str(mv_id)

pred = algo.predict(uid, iid, verbose=True)
# Out:
# user: 9          item: 42         r_ui = None   est = 3.13   {'was_impossible': False}

# %% [markdown]
# 9번 사용자, 42번 영화에 대한 예측평점은 3.13점. <br>
# 전체 영화 추출 후 예측평점 높은 순으로 추천해보자

# %%
# unseen_movie 추출
def get_unseen_surprise(ratings, movies, userId):
    seen_movies = ratings[ratings['userId']== userId]['movieId'].tolist()
    total_movies = movies['movieId'].tolist()
    unseen_movies = [movie for movie in total_movies if movie not in seen_movies]

    print('평점 매긴 영화수',len(seen_movies),'추천 대상 영화수', len(unseen_movies),
    '전체 영화수',len(total_movies))

    return unseen_movies

unseen_movies = get_unseen_surprise(ratings, movies, usr_id)
# Out:
# 평점 매긴 영화수 46 추천 대상 영화수 9696 전체 영화수 9742

# %%
# recommend_movie
def recomm_movie_by_surprise(algo, userId, unseen_movies, top_n=10):
    preds = [algo.predict(str(userId), str(movieId)) for movieId in unseen_movies]

    def sortkey_est(pred): # 예측 평점 순 정렬
        return pred.est

    preds.sort(key = sortkey_est, reverse= True)
    t1_preds = preds[:top_n]

    # 영화 정보 추출 : 아이디, 제목, 예상평점
    t_ids = [int(pred.iid) for pred in t1_preds]
    t_ratings = [pred.est for pred in t1_preds]
    t_titles = movies[movies.movieId.isin(t_ids)]['title']
    t2_preds = [(id, title, rating) for id, title, rating in zip(t_ids, t_titles, t_ratings)]

    return t2_preds

unseen_movies = get_unseen_surprise(ratings, movies, usr_id)
top_movie_preds = recomm_movie_by_surprise(algo,usr_id,unseen_movies,10)

print()
print('##### Top-10 추천 영화 리스트 #####')
for top_movie in top_movie_preds:
    print(top_movie[1],":", top_movie[2])
# Out:
# 평점 매긴 영화수 46 추천 대상 영화수 9696 전체 영화수 9742
#
# ##### Top-10 추천 영화 리스트 #####
# Usual Suspects, The (1995) : 4.306302135700814
# Star Wars: Episode IV - A New Hope (1977) : 4.281663842987387
# Pulp Fiction (1994) : 4.278152632122758
# Silence of the Lambs, The (1991) : 4.226073566460876
# Godfather, The (1972) : 4.1918097904381995
# Streetcar Named Desire, A (1951) : 4.154746591122658
# Star Wars: Episode V - The Empire Strikes Back (1980) : 4.122016128534504
# Star Wars: Episode VI - Return of the Jedi (1983) : 4.108009609093436
# Goodfellas (1990) : 4.083464936588478
# Glory (1989) : 4.07887165526957

# %%
preds = [algo.predict(str(usr_id), str(movieId)) for movieId in unseen_movies]
preds
# Out:
# [Prediction(uid='9', iid='1', r_ui=None, est=3.6398015009715396, details={'was_impossible': False}),
#  Prediction(uid='9', iid='2', r_ui=None, est=3.0708535569743463, details={'was_impossible': False}),
#  Prediction(uid='9', iid='3', r_ui=None, est=2.9912517694217033, details={'was_impossible': False}),
#  Prediction(uid='9', iid='4', r_ui=None, est=2.7584914835669805, details={'was_impossible': False}),
#  Prediction(uid='9', iid='5', r_ui=None, est=2.653809583804632, details={'was_impossible': False}),
#  Prediction(uid='9', iid='6', r_ui=None, est=3.7627640786692917, details={'was_impossible': False}),
#  Prediction(uid='9', iid='7', r_ui=None, est=2.883779132627597, details={'was_impossible': False}),
#  Prediction(uid='9', iid='8', r_ui=None, est=2.9865774263273677, details={'was_impossible': False}),
#  Prediction(uid='9', iid='9', r_ui=None, est=2.7889711267915422, details={'was_impossible': False}),
#  Prediction(uid='9', iid='10', r_ui=None, est=3.3040663633820104, details={'was_impossible': False}),
#  Prediction(uid='9', iid='11', r_ui=None, est=3.301941326194276, details={'was_impossible': False}),
#  Prediction(uid='9', iid='12', r_ui=None, est=2.3294900034682327, details={'was_impossible': False}),
#  Prediction(uid='9', iid='13', r_ui=None, est=3.0744734325496808, details={'was_impossible': False}),
#  Prediction(uid='9', iid='14', r_ui=None, est=3.3201893823035964, details={'was_impossible': False}),
#  Prediction(uid='9', iid='15', r_ui=None, est=2.660269387061533, details={'was_impossible': False}),
#  Prediction(uid='9', iid='16', r_ui=None, est=3.6448604903021535, details={'was_impossible': False}),
#  Prediction(uid='9', iid='17', r_ui=None, est=3.329252576942451, details={'was_impossible': False}),
#  Prediction(uid='9', iid='18', r_ui=None, est=3.3603365626921406, details={'was_impossible': False}),
#  Prediction(uid='9', iid='19', r_ui=None, est=2.441776420459757, details={'was_impossible': False}),
#  Prediction(uid='9', iid='20', r_ui=None, est=2.675169857411195, details={'was_impossible': False}),
#  Prediction(uid='9', iid='21', r_ui=None, est=3.312704307013823, details={'was_impossible': False}),
#  Prediction(uid='9', iid='22', r_ui=None, est=2.952810079926278, details={'was_impossible': False}),
#  Prediction(uid='9', iid='23', r_ui=None, est=2.851193417353712, details={'was_impossible': False}),
#  Prediction(uid='9', iid='24', r_ui=None, est=2.9130176308027567, details={'was_impossible': False}),
#  Prediction(uid='9', iid='25', r_ui=None, est=3.206443673689028, details={'was_impossible': False}),
#  Prediction(uid='9', iid='26', r_ui=None, est=3.3800965535788468, details={'was_impossible': False}),
#  Prediction(uid='9', iid='27', r_ui=None, est=3.2179738325867366, details={'was_impossible': False}),
#  Prediction(uid='9', iid='28', r_ui=None, est=3.62199226745331, details={'was_impossible': False}),
#  Prediction(uid='9', iid='29', r_ui=None, est=3.5490600310549447, details={'was_impossible': False}),
#  Prediction(uid='9', iid='30', r_ui=None, est=3.1205358562771606, details={'was_impossible': False}),
#  Prediction(uid='9', iid='31', r_ui=None, est=2.915147790175212, details={'was_impossible': False}),
#  Prediction(uid='9', iid='32', r_ui=None, est=3.764172386311384, details={'was_impossible': False}),
#  Prediction(uid='9', iid='34', r_ui=None, est=3.407050709737998, details={'was_impossible': False}),
#  Prediction(uid='9', iid='36', r_ui=None, est=3.2931349167664496, details={'was_impossible': False}),
#  Prediction(uid='9', iid='38', r_ui=None, est=3.035940103315345, details={'was_impossible': False}),
#  Prediction(uid='9', iid='39', r_ui=None, est=3.1797944303844567, details={'was_impossible': False}),
#  Prediction(uid='9', iid='40', r_ui=None, est=3.464464568663682, details={'was_impossible': False}),
#  Prediction(uid='9', iid='42', r_ui=None, est=3.130146490888994, details={'was_impossible': False}),
#  Prediction(uid='9', iid='43', r_ui=None, est=3.174362010783309, details={'was_impossible': False}),
#  Prediction(uid='9', iid='44', r_ui=None, est=2.4514566972499727, details={'was_impossible': False}),
#  Prediction(uid='9', iid='45', r_ui=None, est=3.2688115962420956, details={'was_impossible': False}),
#  Prediction(uid='9', iid='46', r_ui=None, est=2.9196528443053285, details={'was_impossible': False}),
#  Prediction(uid='9', iid='47', r_ui=None, est=4.0748082292207135, details={'was_impossible': False}),
#  Prediction(uid='9', iid='48', r_ui=None, est=2.929939436640734, details={'was_impossible': False}),
#  Prediction(uid='9', iid='49', r_ui=None, est=2.9877225532475657, details={'was_impossible': False}),
#  Prediction(uid='9', iid='50', r_ui=None, est=4.1918097904381995, details={'was_impossible': False}),
#  Prediction(uid='9', iid='52', r_ui=None, est=3.051735138175681, details={'was_impossible': False}),
#  Prediction(uid='9', iid='53', r_ui=None, est=3.6107201009449135, details={'was_impossible': False}),
#  Prediction(uid='9', iid='54', r_ui=None, est=2.9167027301424215, details={'was_impossible': False}),
#  Prediction(uid='9', iid='55', r_ui=None, est=3.193399606522109, details={'was_impossible': False}),
#  Prediction(uid='9', iid='57', r_ui=None, est=2.928481750578357, details={'was_impossible': False}),
#  Prediction(uid='9', iid='58', r_ui=None, est=3.789985712540686, details={'was_impossible': False}),
#  Prediction(uid='9', iid='60', r_ui=None, est=2.9521670487670413, details={'was_impossible': False}),
#  Prediction(uid='9', iid='61', r_ui=None, est=3.242638520744823, details={'was_impossible': False}),
#  Prediction(uid='9', iid='62', r_ui=None, est=3.1972011127857765, details={'was_impossible': False}),
#  Prediction(uid='9', iid='63', r_ui=None, est=2.8995826655640413, details={'was_impossible': False}),
#  Prediction(uid='9', iid='64', r_ui=None, est=2.6302709113736147, details={'was_impossible': False}),
#  Prediction(uid='9', iid='65', r_ui=None, est=2.322111171374444, details={'was_impossible': False}),
#  Prediction(uid='9', iid='66', r_ui=None, est=2.586840206205458, details={'was_impossible': False}),
#  Prediction(uid='9', iid='68', r_ui=None, est=3.1739094547606386, details={'was_impossible': False}),
#  Prediction(uid='9', iid='69', r_ui=None, est=3.553690314233372, details={'was_impossible': False}),
#  Prediction(uid='9', iid='70', r_ui=None, est=3.274088747674442, details={'was_impossible': False}),
#  Prediction(uid='9', iid='71', r_ui=None, est=2.498104426524477, details={'was_impossible': False}),
#  Prediction(uid='9', iid='72', r_ui=None, est=3.069177840352328, details={'was_impossible': False}),
#  Prediction(uid='9', iid='73', r_ui=None, est=3.1530958539112914, details={'was_impossible': False}),
#  Prediction(uid='9', iid='74', r_ui=None, est=3.558564041968, details={'was_impossible': False}),
#  Prediction(uid='9', iid='75', r_ui=None, est=2.735373955187064, details={'was_impossible': False}),
#  Prediction(uid='9', iid='76', r_ui=None, est=3.1700161451835145, details={'was_impossible': False}),
#  Prediction(uid='9', iid='77', r_ui=None, est=3.105774747201887, details={'was_impossible': False}),
#  Prediction(uid='9', iid='78', r_ui=None, est=3.178455574503547, details={'was_impossible': False}),
#  Prediction(uid='9', iid='79', r_ui=None, est=2.642142514770127, details={'was_impossible': False}),
#  Prediction(uid='9', iid='80', r_ui=None, est=3.2756459244977436, details={'was_impossible': False}),
#  Prediction(uid='9', iid='81', r_ui=None, est=2.9395092499688675, details={'was_impossible': False}),
#  Prediction(uid='9', iid='82', r_ui=None, est=3.2311406725245697, details={'was_impossible': False}),
#  Prediction(uid='9', iid='83', r_ui=None, est=3.1608060481264464, details={'was_impossible': False}),
#  Prediction(uid='9', iid='85', r_ui=None, est=3.564416281329912, details={'was_impossible': False}),
#  Prediction(uid='9', iid='86', r_ui=None, est=3.370945839596075, details={'was_impossible': False}),
#  Prediction(uid='9', iid='87', r_ui=None, est=2.72965058632372, details={'was_impossible': False}),
#  Prediction(uid='9', iid='88', r_ui=None, est=2.856351917755333, details={'was_impossible': False}),
#  Prediction(uid='9', iid='89', r_ui=None, est=3.2550808872342256, details={'was_impossible': False}),
#  Prediction(uid='9', iid='92', r_ui=None, est=2.8184990710219937, details={'was_impossible': False}),
#  Prediction(uid='9', iid='93', r_ui=None, est=2.848962390422006, details={'was_impossible': False}),
#  Prediction(uid='9', iid='94', r_ui=None, est=3.728240635671457, details={'was_impossible': False}),
#  Prediction(uid='9', iid='95', r_ui=None, est=2.8065479221839817, details={'was_impossible': False}),
#  Prediction(uid='9', iid='96', r_ui=None, est=3.0884999505188295, details={'was_impossible': False}),
#  Prediction(uid='9', iid='97', r_ui=None, est=3.43504011450465, details={'was_impossible': False}),
#  Prediction(uid='9', iid='99', r_ui=None, est=3.603774264529377, details={'was_impossible': False}),
#  Prediction(uid='9', iid='100', r_ui=None, est=2.8078880556244585, details={'was_impossible': False}),
#  Prediction(uid='9', iid='101', r_ui=None, est=3.5572427764262358, details={'was_impossible': False}),
#  Prediction(uid='9', iid='102', r_ui=None, est=2.773255807193603, details={'was_impossible': False}),
#  Prediction(uid='9', iid='103', r_ui=None, est=3.0061564463424566, details={'was_impossible': False}),
#  Prediction(uid='9', iid='104', r_ui=None, est=3.1141726547837703, details={'was_impossible': False}),
#  Prediction(uid='9', iid='105', r_ui=None, est=2.87104289832328, details={'was_impossible': False}),
#  Prediction(uid='9', iid='106', r_ui=None, est=3.209152974431394, details={'was_impossible': False}),
#  Prediction(uid='9', iid='107', r_ui=None, est=3.1460323608485106, details={'was_impossible': False}),
#  Prediction(uid='9', iid='108', r_ui=None, est=3.3479145829444734, details={'was_impossible': False}),
#  Prediction(uid='9', iid='110', r_ui=None, est=3.8837825714431182, details={'was_impossible': False}),
#  Prediction(uid='9', iid='111', r_ui=None, est=3.926520531333277, details={'was_impossible': False}),
#  Prediction(uid='9', iid='112', r_ui=None, est=3.031970314358439, details={'was_impossible': False}),
#  Prediction(uid='9', iid='113', r_ui=None, est=3.0407025070901867, details={'was_impossible': False}),
#  Prediction(uid='9', iid='116', r_ui=None, est=3.360342915471955, details={'was_impossible': False}),
#  Prediction(uid='9', iid='117', r_ui=None, est=3.4065683752464753, details={'was_impossible': False}),
#  Prediction(uid='9', iid='118', r_ui=None, est=2.991670994350962, details={'was_impossible': False}),
#  Prediction(uid='9', iid='119', r_ui=None, est=3.334234063281119, details={'was_impossible': False}),
#  Prediction(uid='9', iid='121', r_ui=None, est=3.217512172820347, details={'was_impossible': False}),
#  Prediction(uid='9', iid='122', r_ui=None, est=2.6539005536006255, details={'was_impossible': False}),
#  Prediction(uid='9', iid='123', r_ui=None, est=3.3435903039586248, details={'was_impossible': False}),
#  Prediction(uid='9', iid='125', r_ui=None, est=3.2582168011018715, details={'was_impossible': False}),
#  Prediction(uid='9', iid='126', r_ui=None, est=2.56491205961534, details={'was_impossible': False}),
#  Prediction(uid='9', iid='128', r_ui=None, est=3.2574973122184008, details={'was_impossible': False}),
#  Prediction(uid='9', iid='129', r_ui=None, est=3.1120043430496267, details={'was_impossible': False}),
#  Prediction(uid='9', iid='132', r_ui=None, est=3.0242377690038977, details={'was_impossible': False}),
#  Prediction(uid='9', iid='135', r_ui=None, est=2.9822536700254876, details={'was_impossible': False}),
#  Prediction(uid='9', iid='137', r_ui=None, est=3.3175490686047424, details={'was_impossible': False}),
#  Prediction(uid='9', iid='140', r_ui=None, est=3.1968971332477905, details={'was_impossible': False}),
#  Prediction(uid='9', iid='141', r_ui=None, est=3.2375582723490055, details={'was_impossible': False}),
#  Prediction(uid='9', iid='144', r_ui=None, est=3.1381946836873467, details={'was_impossible': False}),
#  Prediction(uid='9', iid='145', r_ui=None, est=3.003143903955142, details={'was_impossible': False}),
#  Prediction(uid='9', iid='146', r_ui=None, est=3.18616868054977, details={'was_impossible': False}),
#  Prediction(uid='9', iid='147', r_ui=None, est=3.3974219636563543, details={'was_impossible': False}),
#  Prediction(uid='9', iid='148', r_ui=None, est=3.2676340590181945, details={'was_impossible': False}),
#  Prediction(uid='9', iid='149', r_ui=None, est=2.925913296428197, details={'was_impossible': False}),
#  Prediction(uid='9', iid='150', r_ui=None, est=3.7678709651405033, details={'was_impossible': False}),
#  Prediction(uid='9', iid='151', r_ui=None, est=3.208548005719016, details={'was_impossible': False}),
#  Prediction(uid='9', iid='152', r_ui=None, est=2.9026385768230005, details={'was_impossible': False}),
#  Prediction(uid='9', iid='153', r_ui=None, est=2.754727630363167, details={'was_impossible': False}),
#  Prediction(uid='9', iid='154', r_ui=None, est=3.3822022345896516, details={'was_impossible': False}),
#  Prediction(uid='9', iid='155', r_ui=None, est=2.777864457697089, details={'was_impossible': False}),
#  Prediction(uid='9', iid='156', r_ui=None, est=3.0732267785318563, details={'was_impossible': False}),
#  Prediction(uid='9', iid='157', r_ui=None, est=3.0560501595994447, details={'was_impossible': False}),
#  Prediction(uid='9', iid='158', r_ui=None, est=2.738783408670057, details={'was_impossible': False}),
#  Prediction(uid='9', iid='159', r_ui=None, est=2.8909827439864606, details={'was_impossible': False}),
#  Prediction(uid='9', iid='160', r_ui=None, est=2.661064493201737, details={'was_impossible': False}),
#  Prediction(uid='9', iid='161', r_ui=None, est=3.559367573493314, details={'was_impossible': False}),
#  Prediction(uid='9', iid='162', r_ui=None, est=3.720014889490385, details={'was_impossible': False}),
#  Prediction(uid='9', iid='163', r_ui=None, est=3.5291569881510494, details={'was_impossible': False}),
#  Prediction(uid='9', iid='164', r_ui=None, est=3.206764080599458, details={'was_impossible': False}),
#  Prediction(uid='9', iid='165', r_ui=None, est=3.1098834509652797, details={'was_impossible': False}),
#  Prediction(uid='9', iid='166', r_ui=None, est=2.873675967400736, details={'was_impossible': False}),
#  Prediction(uid='9', iid='168', r_ui=None, est=2.6960957484930708, details={'was_impossible': False}),
#  Prediction(uid='9', iid='169', r_ui=None, est=2.537943690453654, details={'was_impossible': False}),
#  Prediction(uid='9', iid='170', r_ui=None, est=3.199715365095132, details={'was_impossible': False}),
#  Prediction(uid='9', iid='171', r_ui=None, est=3.2595878806218956, details={'was_impossible': False}),
#  Prediction(uid='9', iid='172', r_ui=None, est=2.5929514056656098, details={'was_impossible': False}),
#  Prediction(uid='9', iid='173', r_ui=None, est=2.4160226729100165, details={'was_impossible': False}),
#  Prediction(uid='9', iid='174', r_ui=None, est=2.51023924476794, details={'was_impossible': False}),
#  Prediction(uid='9', iid='175', r_ui=None, est=3.7838680878115096, details={'was_impossible': False}),
#  Prediction(uid='9', iid='176', r_ui=None, est=3.5935385143147904, details={'was_impossible': False}),
#  Prediction(uid='9', iid='177', r_ui=None, est=2.7841506084873786, details={'was_impossible': False}),
#  Prediction(uid='9', iid='178', r_ui=None, est=3.123499326914309, details={'was_impossible': False}),
#  Prediction(uid='9', iid='179', r_ui=None, est=2.646715123434592, details={'was_impossible': False}),
#  Prediction(uid='9', iid='180', r_ui=None, est=3.2844838778238925, details={'was_impossible': False}),
#  Prediction(uid='9', iid='181', r_ui=None, est=2.4467579988091654, details={'was_impossible': False}),
#  Prediction(uid='9', iid='183', r_ui=None, est=3.0906152815618158, details={'was_impossible': False}),
#  Prediction(uid='9', iid='184', r_ui=None, est=3.2435613494646094, details={'was_impossible': False}),
#  Prediction(uid='9', iid='185', r_ui=None, est=2.977947408752955, details={'was_impossible': False}),
#  Prediction(uid='9', iid='186', r_ui=None, est=2.59998046986046, details={'was_impossible': False}),
#  Prediction(uid='9', iid='188', r_ui=None, est=3.1383740657378083, details={'was_impossible': False}),
#  Prediction(uid='9', iid='189', r_ui=None, est=3.084431633568099, details={'was_impossible': False}),
#  Prediction(uid='9', iid='190', r_ui=None, est=2.7711526518951133, details={'was_impossible': False}),
#  Prediction(uid='9', iid='191', r_ui=None, est=2.768057433588332, details={'was_impossible': False}),
#  Prediction(uid='9', iid='193', r_ui=None, est=2.3606742732317016, details={'was_impossible': False}),
#  Prediction(uid='9', iid='194', r_ui=None, est=3.3923948413384872, details={'was_impossible': False}),
#  Prediction(uid='9', iid='195', r_ui=None, est=2.849675929238255, details={'was_impossible': False}),
#  Prediction(uid='9', iid='196', r_ui=None, est=2.42315948745131, details={'was_impossible': False}),
#  Prediction(uid='9', iid='198', r_ui=None, est=3.2330424115424274, details={'was_impossible': False}),
#  Prediction(uid='9', iid='199', r_ui=None, est=3.362254746163124, details={'was_impossible': False}),
#  Prediction(uid='9', iid='201', r_ui=None, est=3.326632819652794, details={'was_impossible': False}),
#  Prediction(uid='9', iid='202', r_ui=None, est=3.033086307856353, details={'was_impossible': False}),
#  Prediction(uid='9', iid='203', r_ui=None, est=3.195358658023722, details={'was_impossible': False}),
#  Prediction(uid='9', iid='204', r_ui=None, est=2.419114643275878, details={'was_impossible': False}),
#  Prediction(uid='9', iid='205', r_ui=None, est=3.1629607530699633, details={'was_impossible': False}),
#  Prediction(uid='9', iid='206', r_ui=None, est=3.184154534082266, details={'was_impossible': False}),
#  Prediction(uid='9', iid='207', r_ui=None, est=3.081693504192831, details={'was_impossible': False}),
#  Prediction(uid='9', iid='208', r_ui=None, est=2.616396198686067, details={'was_impossible': False}),
#  Prediction(uid='9', iid='209', r_ui=None, est=3.1349134132893917, details={'was_impossible': False}),
#  Prediction(uid='9', iid='210', r_ui=None, est=3.027154074683157, details={'was_impossible': False}),
#  Prediction(uid='9', iid='211', r_ui=None, est=3.197332091674546, details={'was_impossible': False}),
#  Prediction(uid='9', iid='212', r_ui=None, est=3.066998853309303, details={'was_impossible': False}),
#  Prediction(uid='9', iid='213', r_ui=None, est=3.3298837975087054, details={'was_impossible': False}),
#  Prediction(uid='9', iid='214', r_ui=None, est=3.190399838745319, details={'was_impossible': False}),
#  Prediction(uid='9', iid='215', r_ui=None, est=3.712357850175416, details={'was_impossible': False}),
#  Prediction(uid='9', iid='216', r_ui=None, est=3.014932835466209, details={'was_impossible': False}),
#  Prediction(uid='9', iid='217', r_ui=None, est=2.616835817264459, details={'was_impossible': False}),
#  Prediction(uid='9', iid='218', r_ui=None, est=3.359571651063331, details={'was_impossible': False}),
#  Prediction(uid='9', iid='219', r_ui=None, est=3.132180925590102, details={'was_impossible': False}),
#  Prediction(uid='9', iid='220', r_ui=None, est=3.3008093708441213, details={'was_impossible': False}),
#  Prediction(uid='9', iid='222', r_ui=None, est=3.233290262686303, details={'was_impossible': False}),
#  Prediction(uid='9', iid='224', r_ui=None, est=3.2614057610682545, details={'was_impossible': False}),
#  Prediction(uid='9', iid='225', r_ui=None, est=3.1947445962588, details={'was_impossible': False}),
#  Prediction(uid='9', iid='227', r_ui=None, est=2.710758060778274, details={'was_impossible': False}),
#  Prediction(uid='9', iid='228', r_ui=None, est=2.8085650475796182, details={'was_impossible': False}),
#  Prediction(uid='9', iid='229', r_ui=None, est=3.147588569207323, details={'was_impossible': False}),
#  Prediction(uid='9', iid='230', r_ui=None, est=3.2175182026904645, details={'was_impossible': False}),
#  Prediction(uid='9', iid='231', r_ui=None, est=2.646923510440093, details={'was_impossible': False}),
#  Prediction(uid='9', iid='232', r_ui=None, est=3.46502109294563, details={'was_impossible': False}),
#  Prediction(uid='9', iid='233', r_ui=None, est=3.351269133555803, details={'was_impossible': False}),
#  Prediction(uid='9', iid='234', r_ui=None, est=2.637599711885776, details={'was_impossible': False}),
#  Prediction(uid='9', iid='235', r_ui=None, est=3.4110987165823823, details={'was_impossible': False}),
#  Prediction(uid='9', iid='236', r_ui=None, est=3.210797601412012, details={'was_impossible': False}),
#  Prediction(uid='9', iid='237', r_ui=None, est=2.938326937089446, details={'was_impossible': False}),
#  Prediction(uid='9', iid='238', r_ui=None, est=3.1608221094683726, details={'was_impossible': False}),
#  Prediction(uid='9', iid='239', r_ui=None, est=3.038775265778999, details={'was_impossible': False}),
#  Prediction(uid='9', iid='240', r_ui=None, est=2.8679281310990272, details={'was_impossible': False}),
#  Prediction(uid='9', iid='241', r_ui=None, est=3.2573111670398447, details={'was_impossible': False}),
#  Prediction(uid='9', iid='242', r_ui=None, est=3.205377710444931, details={'was_impossible': False}),
#  Prediction(uid='9', iid='243', r_ui=None, est=2.9733553775273474, details={'was_impossible': False}),
#  Prediction(uid='9', iid='246', r_ui=None, est=3.9965381996132137, details={'was_impossible': False}),
#  Prediction(uid='9', iid='247', r_ui=None, est=3.7903909752894767, details={'was_impossible': False}),
#  Prediction(uid='9', iid='248', r_ui=None, est=2.85101799531605, details={'was_impossible': False}),
#  Prediction(uid='9', iid='249', r_ui=None, est=3.3393915062486776, details={'was_impossible': False}),
#  Prediction(uid='9', iid='250', r_ui=None, est=2.8889089536623307, details={'was_impossible': False}),
#  Prediction(uid='9', iid='251', r_ui=None, est=3.1704848243735775, details={'was_impossible': False}),
#  Prediction(uid='9', iid='252', r_ui=None, est=3.1448213922985513, details={'was_impossible': False}),
#  Prediction(uid='9', iid='253', r_ui=None, est=3.310927846404809, details={'was_impossible': False}),
#  Prediction(uid='9', iid='254', r_ui=None, est=3.3704391671478904, details={'was_impossible': False}),
#  Prediction(uid='9', iid='255', r_ui=None, est=2.613594268547544, details={'was_impossible': False}),
#  Prediction(uid='9', iid='256', r_ui=None, est=2.6949475397655416, details={'was_impossible': False}),
#  Prediction(uid='9', iid='257', r_ui=None, est=3.1131131893424837, details={'was_impossible': False}),
#  Prediction(uid='9', iid='258', r_ui=None, est=2.6696584401394654, details={'was_impossible': False}),
#  Prediction(uid='9', iid='259', r_ui=None, est=2.925478737516469, details={'was_impossible': False}),
#  Prediction(uid='9', iid='260', r_ui=None, est=4.281663842987387, details={'was_impossible': False}),
#  Prediction(uid='9', iid='261', r_ui=None, est=3.4324825017781597, details={'was_impossible': False}),
#  Prediction(uid='9', iid='262', r_ui=None, est=3.6377321169623356, details={'was_impossible': False}),
#  Prediction(uid='9', iid='263', r_ui=None, est=3.283200518838868, details={'was_impossible': False}),
#  Prediction(uid='9', iid='265', r_ui=None, est=3.5243376240006716, details={'was_impossible': False}),
#  Prediction(uid='9', iid='266', r_ui=None, est=3.173669923965451, details={'was_impossible': False}),
#  Prediction(uid='9', iid='267', r_ui=None, est=2.6558345010933815, details={'was_impossible': False}),
#  Prediction(uid='9', iid='269', r_ui=None, est=3.1733715131683273, details={'was_impossible': False}),
#  Prediction(uid='9', iid='270', r_ui=None, est=3.2681480898641264, details={'was_impossible': False}),
#  Prediction(uid='9', iid='271', r_ui=None, est=3.0105162853426575, details={'was_impossible': False}),
#  Prediction(uid='9', iid='272', r_ui=None, est=3.576254048004457, details={'was_impossible': False}),
#  Prediction(uid='9', iid='273', r_ui=None, est=2.578929668832489, details={'was_impossible': False}),
#  Prediction(uid='9', iid='274', r_ui=None, est=3.049448268994289, details={'was_impossible': False}),
#  Prediction(uid='9', iid='275', r_ui=None, est=2.8154240706827447, details={'was_impossible': False}),
#  Prediction(uid='9', iid='276', r_ui=None, est=3.0275567301575266, details={'was_impossible': False}),
#  Prediction(uid='9', iid='277', r_ui=None, est=2.678015222206375, details={'was_impossible': False}),
#  Prediction(uid='9', iid='278', r_ui=None, est=3.053332276624629, details={'was_impossible': False}),
#  Prediction(uid='9', iid='279', r_ui=None, est=3.0627985578000407, details={'was_impossible': False}),
#  Prediction(uid='9', iid='280', r_ui=None, est=3.381489001675727, details={'was_impossible': False}),
#  Prediction(uid='9', iid='281', r_ui=None, est=3.4699707466631593, details={'was_impossible': False}),
#  Prediction(uid='9', iid='282', r_ui=None, est=3.1867681681557634, details={'was_impossible': False}),
#  Prediction(uid='9', iid='283', r_ui=None, est=3.351381812455821, details={'was_impossible': False}),
#  Prediction(uid='9', iid='284', r_ui=None, est=3.219002343452027, details={'was_impossible': False}),
#  Prediction(uid='9', iid='285', r_ui=None, est=3.3496087721411842, details={'was_impossible': False}),
#  Prediction(uid='9', iid='287', r_ui=None, est=3.140406412809855, details={'was_impossible': False}),
#  Prediction(uid='9', iid='288', r_ui=None, est=3.177821040607557, details={'was_impossible': False}),
#  Prediction(uid='9', iid='289', r_ui=None, est=3.1023236864867765, details={'was_impossible': False}),
#  Prediction(uid='9', iid='290', r_ui=None, est=3.494453726511376, details={'was_impossible': False}),
#  Prediction(uid='9', iid='291', r_ui=None, est=3.0519866657416226, details={'was_impossible': False}),
#  Prediction(uid='9', iid='292', r_ui=None, est=3.1179442977900993, details={'was_impossible': False}),
#  Prediction(uid='9', iid='293', r_ui=None, est=3.58596595450736, details={'was_impossible': False}),
#  Prediction(uid='9', iid='294', r_ui=None, est=3.2616866577104164, details={'was_impossible': False}),
#  Prediction(uid='9', iid='295', r_ui=None, est=3.0638954577652266, details={'was_impossible': False}),
#  Prediction(uid='9', iid='296', r_ui=None, est=4.278152632122758, details={'was_impossible': False}),
#  Prediction(uid='9', iid='298', r_ui=None, est=3.122360487316724, details={'was_impossible': False}),
#  Prediction(uid='9', iid='299', r_ui=None, est=3.3127036348907946, details={'was_impossible': False}),
#  Prediction(uid='9', iid='300', r_ui=None, est=3.3002731760542927, details={'was_impossible': False}),
#  Prediction(uid='9', iid='301', r_ui=None, est=3.1878789857317886, details={'was_impossible': False}),
#  Prediction(uid='9', iid='302', r_ui=None, est=3.125570217084201, details={'was_impossible': False}),
#  Prediction(uid='9', iid='303', r_ui=None, est=2.9407003784319654, details={'was_impossible': False}),
#  Prediction(uid='9', iid='304', r_ui=None, est=3.318603753807527, details={'was_impossible': False}),
#  Prediction(uid='9', iid='305', r_ui=None, est=2.778845033420514, details={'was_impossible': False}),
#  Prediction(uid='9', iid='306', r_ui=None, est=3.6325228662270144, details={'was_impossible': False}),
#  Prediction(uid='9', iid='307', r_ui=None, est=3.388501288346912, details={'was_impossible': False}),
#  Prediction(uid='9', iid='308', r_ui=None, est=3.75483571043624, details={'was_impossible': False}),
#  Prediction(uid='9', iid='310', r_ui=None, est=3.1897211274162074, details={'was_impossible': False}),
#  Prediction(uid='9', iid='311', r_ui=None, est=3.1729700758722776, details={'was_impossible': False}),
#  Prediction(uid='9', iid='312', r_ui=None, est=2.197835613504796, details={'was_impossible': False}),
#  Prediction(uid='9', iid='313', r_ui=None, est=3.2935761504908427, details={'was_impossible': False}),
#  Prediction(uid='9', iid='314', r_ui=None, est=3.2497383370980697, details={'was_impossible': False}),
#  Prediction(uid='9', iid='315', r_ui=None, est=2.700200208363261, details={'was_impossible': False}),
#  Prediction(uid='9', iid='316', r_ui=None, est=2.9416509411616873, details={'was_impossible': False}),
#  Prediction(uid='9', iid='317', r_ui=None, est=3.040222737231917, details={'was_impossible': False}),
#  Prediction(uid='9', iid='318', r_ui=None, est=4.068482622899512, details={'was_impossible': False}),
#  Prediction(uid='9', iid='319', r_ui=None, est=3.4769610476740764, details={'was_impossible': False}),
#  Prediction(uid='9', iid='320', r_ui=None, est=2.7943419162504353, details={'was_impossible': False}),
#  Prediction(uid='9', iid='321', r_ui=None, est=3.141890787108219, details={'was_impossible': False}),
#  Prediction(uid='9', iid='322', r_ui=None, est=3.3313968680793096, details={'was_impossible': False}),
#  Prediction(uid='9', iid='324', r_ui=None, est=3.24628460175137, details={'was_impossible': False}),
#  Prediction(uid='9', iid='325', r_ui=None, est=2.8115957415377926, details={'was_impossible': False}),
#  Prediction(uid='9', iid='326', r_ui=None, est=3.3003990050308074, details={'was_impossible': False}),
#  Prediction(uid='9', iid='327', r_ui=None, est=2.795676119315418, details={'was_impossible': False}),
#  Prediction(uid='9', iid='328', r_ui=None, est=3.0785053400888485, details={'was_impossible': False}),
#  Prediction(uid='9', iid='329', r_ui=None, est=3.030458870372189, details={'was_impossible': False}),
#  Prediction(uid='9', iid='330', r_ui=None, est=3.1119408350380016, details={'was_impossible': False}),
#  Prediction(uid='9', iid='331', r_ui=None, est=3.185555171404337, details={'was_impossible': False}),
#  Prediction(uid='9', iid='332', r_ui=None, est=2.76282359557973, details={'was_impossible': False}),
#  Prediction(uid='9', iid='333', r_ui=None, est=3.2572924555977045, details={'was_impossible': False}),
#  Prediction(uid='9', iid='334', r_ui=None, est=3.5642443215933706, details={'was_impossible': False}),
#  Prediction(uid='9', iid='335', r_ui=None, est=3.3657713611220785, details={'was_impossible': False}),
#  Prediction(uid='9', iid='336', r_ui=None, est=3.1702020980079273, details={'was_impossible': False}),
#  Prediction(uid='9', iid='337', r_ui=None, est=3.3386812323904143, details={'was_impossible': False}),
#  Prediction(uid='9', iid='338', r_ui=None, est=2.6907719874748266, details={'was_impossible': False}),
#  Prediction(uid='9', iid='339', r_ui=None, est=3.1951552961799785, details={'was_impossible': False}),
#  Prediction(uid='9', iid='340', r_ui=None, est=3.222898398724858, details={'was_impossible': False}),
#  Prediction(uid='9', iid='341', r_ui=None, est=3.3596193736733397, details={'was_impossible': False}),
#  Prediction(uid='9', iid='342', r_ui=None, est=3.047425813614559, details={'was_impossible': False}),
#  Prediction(uid='9', iid='343', r_ui=None, est=2.8413223569776354, details={'was_impossible': False}),
#  Prediction(uid='9', iid='344', r_ui=None, est=2.55162434149012, details={'was_impossible': False}),
#  Prediction(uid='9', iid='345', r_ui=None, est=3.427969708625212, details={'was_impossible': False}),
#  Prediction(uid='9', iid='346', r_ui=None, est=3.2541416993779664, details={'was_impossible': False}),
#  Prediction(uid='9', iid='347', r_ui=None, est=3.429414499470829, details={'was_impossible': False}),
#  Prediction(uid='9', iid='348', r_ui=None, est=3.3498438109994537, details={'was_impossible': False}),
#  Prediction(uid='9', iid='349', r_ui=None, est=3.257070288998235, details={'was_impossible': False}),
#  Prediction(uid='9', iid='350', r_ui=None, est=3.2232767031756273, details={'was_impossible': False}),
#  Prediction(uid='9', iid='351', r_ui=None, est=2.921209570014764, details={'was_impossible': False}),
#  Prediction(uid='9', iid='352', r_ui=None, est=3.0614667693294364, details={'was_impossible': False}),
#  Prediction(uid='9', iid='353', r_ui=None, est=3.405532619299813, details={'was_impossible': False}),
#  Prediction(uid='9', iid='354', r_ui=None, est=3.1703762361710544, details={'was_impossible': False}),
#  Prediction(uid='9', iid='355', r_ui=None, est=2.443913147031889, details={'was_impossible': False}),
#  Prediction(uid='9', iid='356', r_ui=None, est=3.7756799565976253, details={'was_impossible': False}),
#  Prediction(uid='9', iid='357', r_ui=None, est=3.3531163121601213, details={'was_impossible': False}),
#  Prediction(uid='9', iid='358', r_ui=None, est=2.4239879667673265, details={'was_impossible': False}),
#  Prediction(uid='9', iid='359', r_ui=None, est=3.1831769022284675, details={'was_impossible': False}),
#  Prediction(uid='9', iid='360', r_ui=None, est=2.9412881476692037, details={'was_impossible': False}),
#  Prediction(uid='9', iid='361', r_ui=None, est=2.843737760334304, details={'was_impossible': False}),
#  Prediction(uid='9', iid='362', r_ui=None, est=3.280611319991715, details={'was_impossible': False}),
#  Prediction(uid='9', iid='363', r_ui=None, est=3.3036808548972534, details={'was_impossible': False}),
#  Prediction(uid='9', iid='364', r_ui=None, est=3.7497208230521397, details={'was_impossible': False}),
#  Prediction(uid='9', iid='365', r_ui=None, est=3.2282363551264743, details={'was_impossible': False}),
#  Prediction(uid='9', iid='366', r_ui=None, est=2.8580237724619737, details={'was_impossible': False}),
#  Prediction(uid='9', iid='367', r_ui=None, est=3.0387303212349956, details={'was_impossible': False}),
#  Prediction(uid='9', iid='368', r_ui=None, est=3.1916487005089174, details={'was_impossible': False}),
#  Prediction(uid='9', iid='369', r_ui=None, est=3.2342298102541815, details={'was_impossible': False}),
#  Prediction(uid='9', iid='370', r_ui=None, est=2.9662552647056, details={'was_impossible': False}),
#  Prediction(uid='9', iid='372', r_ui=None, est=2.8464331468508437, details={'was_impossible': False}),
#  Prediction(uid='9', iid='373', r_ui=None, est=3.297241045096415, details={'was_impossible': False}),
#  Prediction(uid='9', iid='374', r_ui=None, est=2.086662975967967, details={'was_impossible': False}),
#  Prediction(uid='9', iid='376', r_ui=None, est=2.8430292648373987, details={'was_impossible': False}),
#  Prediction(uid='9', iid='377', r_ui=None, est=3.399008747385003, details={'was_impossible': False}),
#  Prediction(uid='9', iid='378', r_ui=None, est=3.156523486556937, details={'was_impossible': False}),
#  Prediction(uid='9', iid='379', r_ui=None, est=2.556202130780149, details={'was_impossible': False}),
#  Prediction(uid='9', iid='380', r_ui=None, est=3.4835308259246256, details={'was_impossible': False}),
#  Prediction(uid='9', iid='381', r_ui=None, est=3.260348143935257, details={'was_impossible': False}),
#  Prediction(uid='9', iid='382', r_ui=None, est=3.0155682199246385, details={'was_impossible': False}),
#  Prediction(uid='9', iid='383', r_ui=None, est=2.925267227604171, details={'was_impossible': False}),
#  Prediction(uid='9', iid='384', r_ui=None, est=3.122155176386509, details={'was_impossible': False}),
#  Prediction(uid='9', iid='385', r_ui=None, est=3.1732035441560806, details={'was_impossible': False}),
#  Prediction(uid='9', iid='386', r_ui=None, est=3.2100575766762725, details={'was_impossible': False}),
#  Prediction(uid='9', iid='387', r_ui=None, est=3.2049777190804063, details={'was_impossible': False}),
#  Prediction(uid='9', iid='388', r_ui=None, est=3.100928592518146, details={'was_impossible': False}),
#  Prediction(uid='9', iid='389', r_ui=None, est=3.468007961564424, details={'was_impossible': False}),
#  Prediction(uid='9', iid='390', r_ui=None, est=3.499768007280624, details={'was_impossible': False}),
#  Prediction(uid='9', iid='391', r_ui=None, est=3.390259126588941, details={'was_impossible': False}),
#  Prediction(uid='9', iid='393', r_ui=None, est=2.643552681676282, details={'was_impossible': False}),
#  Prediction(uid='9', iid='405', r_ui=None, est=2.392197331158307, details={'was_impossible': False}),
#  Prediction(uid='9', iid='406', r_ui=None, est=3.163876124170457, details={'was_impossible': False}),
#  Prediction(uid='9', iid='407', r_ui=None, est=3.07119483311645, details={'was_impossible': False}),
#  Prediction(uid='9', iid='408', r_ui=None, est=3.1887599411585605, details={'was_impossible': False}),
#  Prediction(uid='9', iid='409', r_ui=None, est=3.0104681030150044, details={'was_impossible': False}),
#  Prediction(uid='9', iid='410', r_ui=None, est=2.920801585673392, details={'was_impossible': False}),
#  Prediction(uid='9', iid='412', r_ui=None, est=3.1673612594873366, details={'was_impossible': False}),
#  Prediction(uid='9', iid='413', r_ui=None, est=2.5852571083794946, details={'was_impossible': False}),
#  Prediction(uid='9', iid='414', r_ui=None, est=2.71498897754947, details={'was_impossible': False}),
#  Prediction(uid='9', iid='415', r_ui=None, est=2.4791425025590077, details={'was_impossible': False}),
#  Prediction(uid='9', iid='416', r_ui=None, est=2.804033038117444, details={'was_impossible': False}),
#  Prediction(uid='9', iid='417', r_ui=None, est=3.509262296023923, details={'was_impossible': False}),
#  Prediction(uid='9', iid='418', r_ui=None, est=3.088175166695681, details={'was_impossible': False}),
#  Prediction(uid='9', iid='419', r_ui=None, est=2.668744418843337, details={'was_impossible': False}),
#  Prediction(uid='9', iid='420', r_ui=None, est=2.634764057286589, details={'was_impossible': False}),
#  Prediction(uid='9', iid='421', r_ui=None, est=3.0651939199615788, details={'was_impossible': False}),
#  Prediction(uid='9', iid='422', r_ui=None, est=3.1136954769154657, details={'was_impossible': False}),
#  Prediction(uid='9', iid='423', r_ui=None, est=2.918200931630999, details={'was_impossible': False}),
#  Prediction(uid='9', iid='424', r_ui=None, est=2.8096190569388546, details={'was_impossible': False}),
#  Prediction(uid='9', iid='425', r_ui=None, est=3.005758544841072, details={'was_impossible': False}),
#  Prediction(uid='9', iid='426', r_ui=None, est=3.1990272660409977, details={'was_impossible': False}),
#  Prediction(uid='9', iid='427', r_ui=None, est=2.5851953201894013, details={'was_impossible': False}),
#  Prediction(uid='9', iid='428', r_ui=None, est=3.588450397857943, details={'was_impossible': False}),
#  Prediction(uid='9', iid='429', r_ui=None, est=2.8865042776827097, details={'was_impossible': False}),
#  Prediction(uid='9', iid='430', r_ui=None, est=3.188755117643123, details={'was_impossible': False}),
#  Prediction(uid='9', iid='431', r_ui=None, est=3.3817139001819174, details={'was_impossible': False}),
#  Prediction(uid='9', iid='432', r_ui=None, est=2.4070940500735567, details={'was_impossible': False}),
#  Prediction(uid='9', iid='433', r_ui=None, est=2.97973951055917, details={'was_impossible': False}),
#  Prediction(uid='9', iid='434', r_ui=None, est=2.755928520648584, details={'was_impossible': False}),
#  Prediction(uid='9', iid='435', r_ui=None, est=2.1904370211096897, details={'was_impossible': False}),
#  Prediction(uid='9', iid='436', r_ui=None, est=2.858479602837713, details={'was_impossible': False}),
#  Prediction(uid='9', iid='437', r_ui=None, est=2.7199874330598464, details={'was_impossible': False}),
#  Prediction(uid='9', iid='438', r_ui=None, est=3.0555279319004383, details={'was_impossible': False}),
#  Prediction(uid='9', iid='440', r_ui=None, est=3.2259592329134894, details={'was_impossible': False}),
#  Prediction(uid='9', iid='441', r_ui=None, est=3.7316845364757962, details={'was_impossible': False}),
#  Prediction(uid='9', iid='442', r_ui=None, est=2.9791432510521156, details={'was_impossible': False}),
#  Prediction(uid='9', iid='444', r_ui=None, est=3.021326854938235, details={'was_impossible': False}),
#  Prediction(uid='9', iid='445', r_ui=None, est=2.993168172597032, details={'was_impossible': False}),
#  Prediction(uid='9', iid='446', r_ui=None, est=3.17925754535407, details={'was_impossible': False}),
#  Prediction(uid='9', iid='448', r_ui=None, est=3.269159984376552, details={'was_impossible': False}),
#  Prediction(uid='9', iid='449', r_ui=None, est=3.2138718842425336, details={'was_impossible': False}),
#  Prediction(uid='9', iid='450', r_ui=None, est=2.9970182557187326, details={'was_impossible': False}),
#  Prediction(uid='9', iid='451', r_ui=None, est=3.2048086397816316, details={'was_impossible': False}),
#  Prediction(uid='9', iid='452', r_ui=None, est=3.071125742761259, details={'was_impossible': False}),
#  Prediction(uid='9', iid='453', r_ui=None, est=3.2676227040287906, details={'was_impossible': False}),
#  Prediction(uid='9', iid='454', r_ui=None, est=3.285019890672861, details={'was_impossible': False}),
#  Prediction(uid='9', iid='455', r_ui=None, est=2.477475117207453, details={'was_impossible': False}),
#  Prediction(uid='9', iid='456', r_ui=None, est=3.209050734710842, details={'was_impossible': False}),
#  Prediction(uid='9', iid='457', r_ui=None, est=3.7504283980019597, details={'was_impossible': False}),
#  Prediction(uid='9', iid='458', r_ui=None, est=2.8732992185465287, details={'was_impossible': False}),
#  Prediction(uid='9', iid='459', r_ui=None, est=2.7091796003072153, details={'was_impossible': False}),
#  Prediction(uid='9', iid='460', r_ui=None, est=3.237225109667711, details={'was_impossible': False}),
#  Prediction(uid='9', iid='461', r_ui=None, est=3.026034790531006, details={'was_impossible': False}),
#  Prediction(uid='9', iid='464', r_ui=None, est=3.0628082554850304, details={'was_impossible': False}),
#  Prediction(uid='9', iid='466', r_ui=None, est=2.633680329787123, details={'was_impossible': False}),
#  Prediction(uid='9', iid='467', r_ui=None, est=3.1430449192109737, details={'was_impossible': False}),
#  Prediction(uid='9', iid='468', r_ui=None, est=3.07913379851403, details={'was_impossible': False}),
#  Prediction(uid='9', iid='469', r_ui=None, est=3.1140935883186875, details={'was_impossible': False}),
#  Prediction(uid='9', iid='470', r_ui=None, est=3.0805315501966666, details={'was_impossible': False}),
#  Prediction(uid='9', iid='471', r_ui=None, est=3.3936775099544123, details={'was_impossible': False}),
#  Prediction(uid='9', iid='472', r_ui=None, est=2.881663925067388, details={'was_impossible': False}),
#  Prediction(uid='9', iid='473', r_ui=None, est=2.7457793697553807, details={'was_impossible': False}),
#  Prediction(uid='9', iid='474', r_ui=None, est=3.4913064961458637, details={'was_impossible': False}),
#  Prediction(uid='9', iid='475', r_ui=None, est=3.965821405691894, details={'was_impossible': False}),
#  Prediction(uid='9', iid='476', r_ui=None, est=2.8992202886037046, details={'was_impossible': False}),
#  Prediction(uid='9', iid='477', r_ui=None, est=3.0768898175801453, details={'was_impossible': False}),
#  Prediction(uid='9', iid='478', r_ui=None, est=3.16556054935449, details={'was_impossible': False}),
#  Prediction(uid='9', iid='479', r_ui=None, est=2.8031216954598976, details={'was_impossible': False}),
#  Prediction(uid='9', iid='480', r_ui=None, est=3.552988558684627, details={'was_impossible': False}),
#  Prediction(uid='9', iid='481', r_ui=None, est=3.1232377067084034, details={'was_impossible': False}),
#  Prediction(uid='9', iid='482', r_ui=None, est=3.441759643430614, details={'was_impossible': False}),
#  Prediction(uid='9', iid='484', r_ui=None, est=3.108244365230007, details={'was_impossible': False}),
#  Prediction(uid='9', iid='485', r_ui=None, est=2.8365649172927063, details={'was_impossible': False}),
#  Prediction(uid='9', iid='486', r_ui=None, est=3.1813326950946546, details={'was_impossible': False}),
#  Prediction(uid='9', iid='487', r_ui=None, est=3.1137770629447634, details={'was_impossible': False}),
#  Prediction(uid='9', iid='488', r_ui=None, est=3.056710505208173, details={'was_impossible': False}),
#  Prediction(uid='9', iid='489', r_ui=None, est=2.867045861862278, details={'was_impossible': False}),
#  Prediction(uid='9', iid='490', r_ui=None, est=2.8971321957825418, details={'was_impossible': False}),
#  Prediction(uid='9', iid='491', r_ui=None, est=3.1454438522885204, details={'was_impossible': False}),
#  Prediction(uid='9', iid='492', r_ui=None, est=3.6119819229253975, details={'was_impossible': False}),
#  Prediction(uid='9', iid='493', r_ui=None, est=3.4087301113582313, details={'was_impossible': False}),
#  Prediction(uid='9', iid='494', r_ui=None, est=3.465570911961808, details={'was_impossible': False}),
#  Prediction(uid='9', iid='495', r_ui=None, est=3.4459120609142007, details={'was_impossible': False}),
#  Prediction(uid='9', iid='496', r_ui=None, est=3.2618914138286934, details={'was_impossible': False}),
#  Prediction(uid='9', iid='497', r_ui=None, est=3.6128579726693024, details={'was_impossible': False}),
#  Prediction(uid='9', iid='499', r_ui=None, est=3.149313021251393, details={'was_impossible': False}),
#  Prediction(uid='9', iid='500', r_ui=None, est=3.0113255530128873, details={'was_impossible': False}),
#  Prediction(uid='9', iid='501', r_ui=None, est=3.1543739689678167, details={'was_impossible': False}),
#  Prediction(uid='9', iid='502', r_ui=None, est=2.238898322460034, details={'was_impossible': False}),
#  Prediction(uid='9', iid='504', r_ui=None, est=3.0552129174398694, details={'was_impossible': False}),
#  Prediction(uid='9', iid='505', r_ui=None, est=2.734223119620081, details={'was_impossible': False}),
#  Prediction(uid='9', iid='506', r_ui=None, est=3.3489249519996953, details={'was_impossible': False}),
#  Prediction(uid='9', iid='507', r_ui=None, est=3.0776470883337175, details={'was_impossible': False}),
#  Prediction(uid='9', iid='508', r_ui=None, est=3.604319863192033, details={'was_impossible': False}),
#  Prediction(uid='9', iid='509', r_ui=None, est=3.377697614986608, details={'was_impossible': False}),
#  Prediction(uid='9', iid='510', r_ui=None, est=3.1801958398031767, details={'was_impossible': False}),
#  Prediction(uid='9', iid='511', r_ui=None, est=3.0723009029973363, details={'was_impossible': False}),
#  Prediction(uid='9', iid='512', r_ui=None, est=3.0417202115510236, details={'was_impossible': False}),
#  Prediction(uid='9', iid='513', r_ui=None, est=3.232156285938108, details={'was_impossible': False}),
#  Prediction(uid='9', iid='514', r_ui=None, est=3.3137570629821718, details={'was_impossible': False}),
#  Prediction(uid='9', iid='515', r_ui=None, est=3.2034386957513963, details={'was_impossible': False}),
#  Prediction(uid='9', iid='516', r_ui=None, est=3.1280106780469943, details={'was_impossible': False}),
#  Prediction(uid='9', iid='517', r_ui=None, est=3.185900335534694, details={'was_impossible': False}),
#  Prediction(uid='9', iid='518', r_ui=None, est=2.8744503013899134, details={'was_impossible': False}),
#  Prediction(uid='9', iid='519', r_ui=None, est=2.2674611439178194, details={'was_impossible': False}),
#  Prediction(uid='9', iid='520', r_ui=None, est=2.680286964675666, details={'was_impossible': False}),
#  Prediction(uid='9', iid='521', r_ui=None, est=3.3945575617345174, details={'was_impossible': False}),
#  Prediction(uid='9', iid='522', r_ui=None, est=3.1918238415956766, details={'was_impossible': False}),
#  Prediction(uid='9', iid='523', r_ui=None, est=3.2531869096983077, details={'was_impossible': False}),
#  Prediction(uid='9', iid='524', r_ui=None, est=3.4352323237550655, details={'was_impossible': False}),
#  Prediction(uid='9', iid='526', r_ui=None, est=3.193787532792976, details={'was_impossible': False}),
#  Prediction(uid='9', iid='527', r_ui=None, est=3.8642894396732856, details={'was_impossible': False}),
#  Prediction(uid='9', iid='528', r_ui=None, est=3.064219506561572, details={'was_impossible': False}),
#  Prediction(uid='9', iid='529', r_ui=None, est=3.522476364818154, details={'was_impossible': False}),
#  Prediction(uid='9', iid='531', r_ui=None, est=2.965520588612523, details={'was_impossible': False}),
#  Prediction(uid='9', iid='532', r_ui=None, est=3.017771595961001, details={'was_impossible': False}),
#  Prediction(uid='9', iid='533', r_ui=None, est=3.018277611247239, details={'was_impossible': False}),
#  Prediction(uid='9', iid='534', r_ui=None, est=3.2980851740846835, details={'was_impossible': False}),
#  Prediction(uid='9', iid='535', r_ui=None, est=3.182772511519288, details={'was_impossible': False}),
#  Prediction(uid='9', iid='536', r_ui=None, est=3.416720429573364, details={'was_impossible': False}),
#  Prediction(uid='9', iid='537', r_ui=None, est=2.994222964176525, details={'was_impossible': False}),
#  Prediction(uid='9', iid='538', r_ui=None, est=3.2439994194095316, details={'was_impossible': False}),
#  Prediction(uid='9', iid='539', r_ui=None, est=3.324895509778143, details={'was_impossible': False}),
# ...
#  Prediction(uid='9', iid='1126', r_ui=None, est=3.168235689721832, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1127', r_ui=None, est=3.397838141118953, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1128', r_ui=None, est=2.6792447267559525, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1129', r_ui=None, est=3.4746850481164757, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1130', r_ui=None, est=2.979293447819696, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1131', r_ui=None, est=3.48943882915335, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1132', r_ui=None, est=3.5627309019153612, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1135', r_ui=None, est=2.9621663638314293, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1136', r_ui=None, est=3.7931182559193384, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1137', r_ui=None, est=3.281421852997996, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1140', r_ui=None, est=3.3338608360103885, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1144', r_ui=None, est=3.0527693517967838, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1147', r_ui=None, est=3.4700937307493187, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1148', r_ui=None, est=3.776376847974534, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1150', r_ui=None, est=3.3592981176168952, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1151', r_ui=None, est=3.327703865549919, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1156', r_ui=None, est=3.2215333189703412, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1161', r_ui=None, est=3.398131385347703, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1162', r_ui=None, est=3.3086043171901367, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1163', r_ui=None, est=2.755832913809775, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1167', r_ui=None, est=3.0527013391990114, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1170', r_ui=None, est=2.856732145946532, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1171', r_ui=None, est=3.27403270851246, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1172', r_ui=None, est=3.473916221151775, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1173', r_ui=None, est=2.8471569437457087, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1175', r_ui=None, est=3.668191933453129, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1176', r_ui=None, est=3.166128343298796, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1177', r_ui=None, est=3.2241609208375084, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1178', r_ui=None, est=3.9957078470628398, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1179', r_ui=None, est=3.570968583294988, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1180', r_ui=None, est=3.278331553541398, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1183', r_ui=None, est=3.5476344939445297, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1184', r_ui=None, est=3.2820427757075787, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1185', r_ui=None, est=3.459709765888572, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1186', r_ui=None, est=3.5599893753944087, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1187', r_ui=None, est=3.3692162211117456, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1188', r_ui=None, est=3.274749560205621, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1189', r_ui=None, est=3.630036690797078, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1190', r_ui=None, est=3.2045605355842017, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1191', r_ui=None, est=3.1513880734122965, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1192', r_ui=None, est=3.391785422433103, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1193', r_ui=None, est=3.823492110007493, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1194', r_ui=None, est=3.4333803930334184, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1196', r_ui=None, est=4.226073566460876, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1197', r_ui=None, est=4.020962389622283, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1199', r_ui=None, est=4.0384294387319, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1200', r_ui=None, est=3.856092739838778, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1201', r_ui=None, est=4.019865831412593, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1202', r_ui=None, est=3.3752445785804435, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1203', r_ui=None, est=3.7977967167307485, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1204', r_ui=None, est=4.022370140213965, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1206', r_ui=None, est=3.7060535518045006, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1207', r_ui=None, est=3.741565391349191, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1208', r_ui=None, est=3.9704308173556404, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1209', r_ui=None, est=3.7711498870924354, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1210', r_ui=None, est=4.122016128534504, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1211', r_ui=None, est=3.451607986819237, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1212', r_ui=None, est=3.706647101883294, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1213', r_ui=None, est=4.108009609093436, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1214', r_ui=None, est=3.5468548670334994, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1215', r_ui=None, est=3.781217425321755, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1216', r_ui=None, est=3.323284609885113, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1217', r_ui=None, est=3.809974058768395, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1218', r_ui=None, est=3.5008699692566343, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1219', r_ui=None, est=3.915220762564583, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1220', r_ui=None, est=3.6251134225136896, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1221', r_ui=None, est=3.96854636293667, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1222', r_ui=None, est=3.930287319448157, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1223', r_ui=None, est=3.977069183294669, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1224', r_ui=None, est=3.389891135143248, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1225', r_ui=None, est=3.8360844474352436, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1226', r_ui=None, est=3.228673153443997, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1227', r_ui=None, est=3.71344984021133, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1228', r_ui=None, est=3.9703092167314216, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1230', r_ui=None, est=3.6232343729315186, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1231', r_ui=None, est=3.6291796331481674, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1232', r_ui=None, est=3.4982783061633516, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1233', r_ui=None, est=4.073126536052557, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1234', r_ui=None, est=3.757017073621824, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1235', r_ui=None, est=3.7469797918639425, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1236', r_ui=None, est=3.463725814152038, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1237', r_ui=None, est=3.8374832413194433, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1238', r_ui=None, est=3.661640104606824, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1240', r_ui=None, est=3.8386254472571224, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1241', r_ui=None, est=3.5723470114999194, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1242', r_ui=None, est=4.083464936588478, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1243', r_ui=None, est=3.446756175649586, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1244', r_ui=None, est=3.7563973507462887, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1245', r_ui=None, est=3.6674705104659764, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1246', r_ui=None, est=3.406928218659809, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1247', r_ui=None, est=3.9266524198689283, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1248', r_ui=None, est=3.7725669582524124, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1249', r_ui=None, est=4.015274767523538, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1250', r_ui=None, est=3.894127707846125, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1251', r_ui=None, est=3.54005214250244, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1252', r_ui=None, est=3.900313246938087, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1253', r_ui=None, est=3.6908581342877027, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1254', r_ui=None, est=3.3450622214340244, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1255', r_ui=None, est=3.0428670346089395, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1256', r_ui=None, est=3.4512382089937144, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1257', r_ui=None, est=3.3461140733385255, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1258', r_ui=None, est=3.565493700260662, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1259', r_ui=None, est=3.875925639348091, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1260', r_ui=None, est=3.3896393610548823, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1261', r_ui=None, est=3.7734013964664146, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1262', r_ui=None, est=4.023476418131559, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1263', r_ui=None, est=3.587353503577842, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1264', r_ui=None, est=3.275846792011075, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1265', r_ui=None, est=3.8661952635529846, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1266', r_ui=None, est=3.960644237661135, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1267', r_ui=None, est=3.772549621418599, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1268', r_ui=None, est=3.326767242522666, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1269', r_ui=None, est=3.6369226334653124, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1271', r_ui=None, est=3.2332334708439645, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1272', r_ui=None, est=3.8500285521696296, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1273', r_ui=None, est=3.7713398886505782, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1274', r_ui=None, est=3.6454136961865977, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1275', r_ui=None, est=3.651153947563006, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1276', r_ui=None, est=3.9660902688583777, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1277', r_ui=None, est=3.786415037535408, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1278', r_ui=None, est=3.875413882106259, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1279', r_ui=None, est=3.434032148631401, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1280', r_ui=None, est=3.648769180798565, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1281', r_ui=None, est=3.718990322972889, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1282', r_ui=None, est=3.3533906635769455, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1283', r_ui=None, est=3.9050993787947177, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1284', r_ui=None, est=3.447221913283654, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1285', r_ui=None, est=3.473992680404034, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1286', r_ui=None, est=2.9464759126605444, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1287', r_ui=None, est=3.590923157338629, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1288', r_ui=None, est=3.890153362585161, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1289', r_ui=None, est=3.3831403851359294, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1290', r_ui=None, est=3.0554476770902474, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1291', r_ui=None, est=4.056337057643723, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1292', r_ui=None, est=3.6632136835211293, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1293', r_ui=None, est=3.4242344154102278, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1295', r_ui=None, est=3.1312732124714007, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1296', r_ui=None, est=3.3773858284495137, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1297', r_ui=None, est=3.4064762574157865, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1298', r_ui=None, est=3.44006703797391, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1299', r_ui=None, est=3.5299912724619213, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1300', r_ui=None, est=3.335860395625256, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1301', r_ui=None, est=3.4268255278312165, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1302', r_ui=None, est=3.289938676325209, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1303', r_ui=None, est=3.9121740392472484, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1304', r_ui=None, est=3.5418952501706027, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1305', r_ui=None, est=2.9966237010731405, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1306', r_ui=None, est=2.8401801990079174, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1307', r_ui=None, est=3.4177406532991257, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1310', r_ui=None, est=3.429946978898789, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1312', r_ui=None, est=3.173474839660633, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1318', r_ui=None, est=3.0221131461473414, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1320', r_ui=None, est=2.975843386095255, details={'was_impossible': False}),
#  Prediction(uid='9', iid='1321', r_ui=None, est=3.2274969846499935, details={'was_impossible': False}),
#  ...]
